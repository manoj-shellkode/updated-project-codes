# %%
import boto3
from langchain_community.document_loaders import AmazonTextractPDFLoader

textract_client = boto3.client("textract", region_name="us-west-2")
textract_features=["FORMS"]
file_path ="s3://my-s3-doc-loader/dtdc-2.pdf"
loader = AmazonTextractPDFLoader(file_path,textract_features,client=textract_client)
docs = loader.load()

# %%
all_page_content = ""
for doc in docs:
    all_page_content += doc.page_content
print(all_page_content)
# Out:
# Drock
# DTDC COURIER & CARGO LTD
# dtdc lite
# Non Negotiable Consignment Note / Subject to Bengaluru Jurisdiction
# Please refer to all the terms & conditions printed overleaf of
#
#
# ORIGIN: Deo
#
#
# DEST: Ghaziabad
#
#
# Regd.Office: No-3,Victoria Road, Bengaluru-56004
# muck
# this consignment note before tendering a shipment to DTDC
#
#
# Date: 3/11/14
#
#
# lender's Code:
#
#
# Sender's Name: Neelansing
#
#
# Pick-up Ref Num.:
# Recipient's 2 Name: V dai Singh
#
#
# Recipient's Name: V dai Singh
#
#
# Company Name: flat No.
# 1
#
#
# Company Name: Surin milk union
#
#
# Address:
# Company Address: Golf Green Apartments.
# Name: flat No. 1705
#
#
# City: Ghaziabad
#
#
# State:
#
#
# Recipient's VAT/CST/TIN Number 9811861902
# crossing
#
#
# PIN Code: 201016
#
#
# City:
#
#
# State:
#
#
# PIN Code:
#
#
# sender's VAT / CST / TIN Number
#
#
# Total Num Pcs:
#
#
# Non-Dox [ ]
#
#
# Dox [ ]
# 4
#
#
# Description of Content Cloths
#
#
# Value of Goods
# 3
# Shipment Type
# DIM 1: L
#
#
# cm x B
#
#
# cm x H
# cm x
#
#
# Pcs
#
#
# Actual Wt.: 800 guls
#
#
# Volumetric Wt.: Kgs
# DIM 2:
# I
# cm X B
# cm X H
#
#
# cm x
#
#
# Pcs
#
#
# Total Value of Goods ₹
#
#
# CN Expiry Dt.
#
#
# CN No.: K71373399
# -
# 5
#
#
# Declared Value for Carriage: ₹
# Risk Coverage: Owner
#
#
# Owner [ ]
#
#
# Carrier [ ]
# Ref. condition no: 16 overleaf for detailed risk surcharge chart applicable
#
#
# 6 Value Added Services
# 7
# 7.3 Mode : Surface
#
#
# Surface [ ]
#
#
# Air cargo [ ]
#
#
# Express [ ]
#
#
# Not Available
# 8
# Charges
#
#
# Amount (₹)
#
#
# 9 I/We declare that this consignment does not contain personal mail, cash, jewellery, contraband, illegal drugs, any prohibited items and commodities which can cause safety hazards while transported by air
#
#
# Courier Signature Ah
#
#
# a) Tariff (incl. Of FSC & ST)
# 10
#
#
# Booking Branch Name / Code, Address
#
#
# b) Risk Surcharge
#
#
# Booking Franchiseo Name: RR
#
#
# Franchisee Code:
#
#
# c) Service Tax on b
#
#
# Sender's Signature:
#
#
# Franchisee Service Tax No.:
#
#
# Total Amount (a+b+c)
# FO
#
#
# 11 Please cal us on 33004444 from your city, prefixing STD code of our nearest customer service centre located in Kolkata, Ahmadabad, Mumbai, Pune, Nagpur, Hyderabad, Bengaluru, Chennai and Kochi and on 44900000 to contact our Delhi customer service centre. Visit us at www.dtdc.com for more information
#
#
# ₹ in words
#
#
# Date:
# Mode of Payment: Cash
#
#
# Cash [ ]
#
#
# Credit Card [ ]
#
#
# Time:
#
#
# AM/PM
# Send" DTDC CONSIGNMENT No" To 9845324040 For SMS Tracking.
#
#
# Send" DTDC CONSIGNMENT No"
#
#
# To 9845324040
#
#
# Visit us at: www.dtdc.com
#
#
# E-mail css.co@dtdc.com
# I
# SENDER COPY Jan-14 Release
#
#
# SENDER COPY
