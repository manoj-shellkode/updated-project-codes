# %%
from langchain_community.document_loaders.excel import UnstructuredExcelLoader
from langchain_community.document_loaders import AmazonTextractPDFLoader
from langchain_community.document_loaders import PDFPlumberLoader
from langchain.prompts import PromptTemplate
from langchain.llms.bedrock import Bedrock
from langchain.chains import LLMChain
import boto3
import botocore

config = botocore.config.Config(
    read_timeout=900,
    connect_timeout=900,
    retries={"max_attempts": 3}
)

bedrock_client = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1",
    config=config,
)

textract_client = boto3.client("textract", region_name="us-west-2")
textract_features=["LAYOUT"]
file_path = "s3://my-s3-doc-loader/Fully executed- ADIC Lease 07-02-01.pdf"
loader = AmazonTextractPDFLoader(file_path,textract_features,client=textract_client)
docs = loader.load()

file_path = r"C:\Users\Lenovo\Documents\Project-vs code\Amazon Transcribe\Bryckle\Clause_pdf.pdf"
loader = PDFPlumberLoader(file_path)
clauses = loader.load()

# %%
template = """
    You are provided with two input documents: a rental agreement document{docs} and a separate clauses document{clauses}. Your task is to compare the clauses specified in the clauses document with those present in the rental agreement document. Follow these steps to accomplish the task:

       - Parse the text of both documents to extract individual clauses.
       - Match corresponding clauses between the rental agreement and clauses document.
       - Analyze each pair of matched clauses to identify similarities and differences.
       - Generate a structured output presenting the comparison results, including:
            - For matched clauses: indicate similarities or differences in language or content.
            - For clauses present in one document but not the other: notify that the document is silent on the specific question.
       - Ensure the tool handles unanswered questions gracefully, encouraging users to review both documents for any overlooked clauses.
       - The output should be presented in a clear and understandable format, facilitating easy interpretation by users.
       - Prioritize accuracy in the comparison process, minimizing errors in clause extraction and matching.
       - Provide good and accurate answers
       - if you make sure and verified that the answer for the clause(question) is not found on the given rental agreement print 'this document is silent on this'
       - Try to give the brief answers so that user can understand easily
       - provide answers in the format like 
                                        question:(mention in detail)
                                        answer:(provide detailed answers)
          and assign serial number for all
     


"""
qa_prompt = PromptTemplate(template=template, input_variables=["docs","clauses"])
llm = Bedrock(model_id="anthropic.claude-v2:1",client=bedrock_client,model_kwargs = {"temperature":1e-10,"max_tokens_to_sample": 40000})
llm_chain = LLMChain(prompt=qa_prompt, llm=llm, verbose= False)
result = llm_chain.run(docs=docs,clauses=clauses)
print(result)
# Out:
#  Here is the comparison of clauses between the clauses document and the rental agreement document:
#
# 1. Address of Premises:
#    Question: Describe the complete physical address of the premises leased with city, state, zipcode as per the document
#    Answer: The address of the premises is 8560 Upland Drive, Parker, Colorado 80134
#
# 2. Rentable Area:
#    Question: What is the square footage or number of seats/workstation leased? Explain the terms and conditions associated with how it is calculated.
#    Answer: The rentable area of the premises is approximately 148,204 square feet, consisting of the West Building (64,327 sf), East Building (64,327 sf) and Connector (19,550 sf). The final measurement will be determined as per Section 1.1 of the agreement after construction is complete.
#
# 3. Tenant:
#    Question: What is full and accurate legal name of the lessee's company that executed this lease?
#    Answer: The tenant is Advanced Digital Information Corporation, a Washington corporation
#
# 4. Landlord:
#    Question: What is full and accurate legal name of the lessor's company that executed this lease?
#    Answer: The landlord is Opus Northwest, L.L.C., a Delaware limited liability company
#
# 5. Lease Commencement Date:
#    Question: What is the lease start date and describe the conditions based on which it is calculated in the agreement in a few sentences.
#    Answer: The lease commencement date is the date on which Substantial Completion of the Premises occurs, as defined in Section 1.2.2. It is projected to be November 30, 2001 but may be later based on delays.
#
# 6. Rent Abatement:
#    Question: Is there rent abatement granted? Describe the conditions based on which it is calculated and how long is the abatement period in a few sentences?
#    Answer: Yes, Tenant is entitled to one day's free Basic Rent for each day of delay past the Projected Commencement Date of November 30, 2001, excluding any delays caused by Tenant Delay or Force Majeure events, up to a maximum of 30 days. After 30 days, Tenant is entitled to two days' free Basic Rent for each additional day of delay.
#
# 7. Rent Commencement Date:
#    Question: What is the rent start date and describe the conditions based on which it is calculated in the agreement in a few sentences?
#    Answer: The rent commencement date is the same as the lease commencement date, which is the date on which Substantial Completion of the Premises occurs.
#
# 8. Lease Expiration Date:
#    Question: What is the lease end date and describe the conditions based on which it is calculated in the agreement in a few sentences?
#    Answer: The lease will expire on the last day of the month that is 10 years after the month in which the Commencement Date occurs, unless terminated earlier.
#
# 9. Initial Term:
#    Question: What is the duration of the initial term specified in the agreement and any conditions associated with it- describe and convert the term from years into exact number of months
#    Answer: The initial term is 10 years, which is 120 months. There are no conditions associated with the initial term.
#
# 10. Lock In Period:
#     Question: Does the lease reference a "lock in period" within the intital term which implies that the agreement can be terminated with notice after lock in period, describe its terms and conditions."
#     Answer: This document is silent on this. The agreement is binding until the expiration date.
#
# 11. Rent Payment Date:
#     Question: What is the frequency and specific date of rent payment?
#     Answer: Rent is payable in monthly installments, in advance, on the first day of each calendar month.
#
# 12. Currency:
#     Question: What is the currency the lease rent is quoted in? Capture in acronym not symbol or text.
#     Answer: The currency used in the lease is United States Dollar (USD).
#
# 13. Base Rent:
#     Question: What is the base rent/fee at the beginning period of the agreement? Provide a detailed summary of the terms and conditions associated with how it is stated.
#     Answer: The base rent rate for the first Lease Year is $8.25 per rentable square foot per year. So the initial monthly base rent will be $102,423.50 based on 148,204 sf. The base rent rate increases by 2% each subsequent Lease Year of the initial term.
#
# 14. Base Rent Escalation:
#     Question: Identify and extract all information about the adjustments, escalations, variable conditions that affect the starting base rent over time. Extract any table that exists for rent increases or changes during the lease term
#     Answer: The base rent rate increases by 2% each Lease Year during the initial term. There are no tables showing the increases.
#
# 15. Tenants' Proportionate Share:
#     Question: If applicable, what is the percentage of shared expenses the tenant is responsible for, based on their leased space compared to the total leasable area?
#     Answer: This document is silent on this.
#
# 16. Additional Rent:
#     Question: Explain how operating expenses, CAM or service fee will be calculated by the landlord, presented to tenant and when is it payable. State the amount, if it is mentioned and specify if it is monthly or by size such as per square foot or square meter or per workstation.
#     Answer: Tenant shall pay Property Expenses, defined as Property Taxes and Landlord's insurance premiums. Landlord will estimate the expenses annually and Tenant shall pay 1/12th of the estimated amount monthly. After each calendar year, Landlord will provide a statement of actual expenses and Tenant will pay or receive a credit for any difference from the estimated amounts.
#
# 17. Additional Rent: Operating Expenses/Service Fee/CAM escalation:
#     Question: Identify and extract all information about the adjustments, escalations, or variable conditions that affect the starting CAM/maintenance fee/operating expenses/service fee over time.
#     Answer: This document is silent on any escalation of additional rent amounts.
#
# 18. Additional Rent: Landlords' Insurance:
#     Question: Is property insurance cost for the tenants share included in base rent or operating expenses?
#     Answer: Property insurance costs are included in Property Expenses which are paid by Tenant as Additional Rent.
#
# 19. Additional Rent: Property Tax:
#     Question: Is property tax cost for the tenants share included in base rent or operating expenses?
#     Answer: Property taxes are included in Property Expenses which are paid by Tenant as Additional Rent.
#
# 20. Additional Rent: Parking:
#     Question: Identify and extract all information about parking. Are there any assigned parking spots specified in the document, for what type of vehicles, their location, fee and conditions for fee increases?
#     Answer: This document is silent on parking.
#
# 21. Variable Rent: Utilities:
#     Question: Is there any variable rent payable payable directly to the landlord based on lessee's consumption of utlities such as electricity, airconditioning,water and internet? How is it calculated and payable?
#     Answer: Tenant shall obtain and pay directly for all utility services. Variable rent to Landlord based on consumption is not mentioned.
#
# 22. Variable Rent: Percentage of gross sales/receipts:
#     Question: Is there any reference to paying percentage of sales/revenue as additional rent to lessor?
#     Answer: This document is silent on this.
#
# 23. One time Fee:
#     Question: Is there a one time set up/onboarding or activation fee charged and what are the details?
#     Answer: This document is silent on this.
#
# 24. Tenant Improvement Allowance:
#     Question: If there an amount of the tenant improvement allowance/construction allowance specified in the agreement, explain any conditions or requirements associated with the use?
#     Answer: Yes, there is a Tenant Improvement Allowance of $2,300,000 provided that will be applied towards the cost of constructing the Leasehold Improvements, with any excess cost being paid by Tenant.
#
# 25. Security Deposit:
#     Question: What is the security deposit/ service retainer to be paid and is it refundable? Capture if it is paid in instalments and also the type of instrument- money order, check or letter of credit?
#     Answer: This document is silent on any security deposit.
#
# 26. Prepaid Rent:
#     Question: Excluding the security deposit, is any type of rent due in advance at the execution of this agreement such as first and last month? How many months rent is it and how will it be applied?
#     Answer: This document is silent on any prepaid rent.
#
# 27. Late Payment:
#     Question: What is the penalty for rent payment after the due date, grace period and notification requirements?
#     Answer: If rent is not paid within 5 business days after due date, Tenant shall pay a late charge equal to 5% of the delinquent amount. If rent is unpaid for 30 days after due date, Tenant shall also pay interest at the Maximum Rate.
#
# 28. Residual Value Guarantee:
#     Question: Is there any reference to residual value guarantee i.e. after all rent payments, a guarantee of value of the underlying asset returned to the lessor at the end of the lease will be at least a specified amount?
#     Answer: This document is silent on this.
#
# 29. Renewal Option:
#     Question: Is there an option for renewal or extension after the initial term and what are the conditions- describe in a few sentences?
#     Answer: Yes, Tenant has the option to extend the lease for two additional 5-year renewal terms. Tenant must notify Landlord in writing no later than 9 months prior to expiration of the then-current term.
#
# 30. Purchase Option:
#     Question: Does the lessee have option of purchasing the space and under what conditions?
#     Answer: There is no mention of a purchase option.
#
# 31. Permitted Use:
#     Question: Extract all information about the permitted business operations or activities allowed and any restrictions
#     Answer: The permitted use is general office, research and development, wholesale sales, manufacturing and warehouse use.
#
# 32. Exclusive Use:
#     Question: Does the lease state any provision of exclusive use for lessee?
#     Answer: This document is silent on this.
#
# 33. Building Hours:
#     Question: What are the building hours of operation?
#     Answer: This document is silent on this.
#
# 34. Compliance with Laws and Regulations:
#     Question: Summarize all clauses that references federal, state, city lor town laws and regulations the tenant needs to comply with
#     Answer: Tenant shall comply with all applicable federal, state and local laws, regulations, rules and orders. Tenant shall obtain all permits required for its use of the premises.
#
# 35. Alterations and Improvements:
#     Question: Summarize all clauses that references alterations or improvements permitted, restrictions, performance of work limitations and enforcement.
#     Answer: Tenant may not make any Structural Alterations. Other Alterations require Landlord's consent, which may not be unreasonably withheld. Alterations must meet certain requirements regarding quality, insurance, liens, etc. specified in the lease. At end of lease, Tenant may be required to remove specified Alterations.
#
# 36. Access and Entry:
#     Question: Summarize all clauses that reference landlords rights to access and entry as well as any limitations on it.
#     Answer: Landlord may enter to inspect, show premises to prospective purchasers/tenants, post notices, perform obligations under lease, etc. Entry during emergencies does not require notice.
#
# 37. Subleasing and Assignment:
#     Question: Summarize the clause on subleasing and assignments. Identify and extract all information for obtaining consent or approval for both, the specific conditions and procedures for getting approval from the original landlord
#     Answer: Tenant may not cause or allow any Transfer without Landlord's prior written consent, which may be granted or withheld in Landlord's reasonable discretion based on factors like financial strength of transferee, compatibility with other tenants, etc. Consent process involves providing details to Landlord regarding proposed transfer. Landlord has right to recapture any portion of premises in connection with a proposed Transfer.
#
# 38. Holdover:
#     Question: Summarize the holdover clause. Identify and extract all information on the duration and conditions under which a holdover fee may apply, the amount and consequences associated with holdover.
#     Answer: If Tenant continues occupying premises after lease expiration without executing a new lease, Tenant shall pay 125% of then-existing Basic Rent for the first 3 months of holdover, and 200% of Basic Rent thereafter. Tenant shall also pay all Additional Rent.
#
# 39. Surrender of Premises:
#     Question: Summarize the clause on surrender of premises. Extract the dates or timeline, condition in which to surrender the space, repairs and restoration, removal of property, notice & inspection and keys & access
#     Answer: Upon lease expiration or earlier termination, Tenant shall surrender possession of premises in good order and condition, remove all its property, repair any damages, and surrender all keys. Any property left behind is deemed abandoned and may be removed by Landlord.
#
# 40. Co-Tenancy:
#     Question: Are there any terms and conditions of the co-tenancy specified in the document and the consequences or implications of changes in co-tenancy?
#     Answer: This document is silent on this.
#
# 41. Repairs & Maintenance:
#     Question: What does the agreement specify regarding the obligation of the tenant for regular upkeep/regular maintenance/AMC's of certain systems or facilities within the space by the tenant? Describe all.
#     Answer: Tenant is responsible for maintenance and non-capital repairs of the Building, including interior and exterior surfaces, flooring, electrical/mechanical systems, plumbing fixtures, parking/drive areas, landscaping, etc. Tenant shall have a preventative maintenance contract for the HVAC system.
#
# 42. Tenants' Insurance:
#     Question: What insurance coverage is the tenant required to obtain for coverage of their business or leased space? List all of them such as general liability, workers comp etc, the amount of coverage specified and who all should be covered - describe all the conditions?
#     Answer: Tenant shall obtain commercial general liability insurance with minimum limits of $3 million per occurrence, naming Landlord as additional insured. Tenant shall provide certificates of insurance prior to occupancy.
#
# 43. Utilities:
#     Question: What is the responsibility of tenant to obtain utilities directly from providers, list all specific ones and any conditions.
#     Answer: Tenant is solely responsible for obtaining all utility services from providers and paying all charges directly.
#
# 44. Services:
#     Question: Summarize the tenant services and amenities provided by the landlord, legal and financial compliance by landlord, emergency response and security.
#     Answer: No tenant services or amenities provided by Landlord are mentioned.
#
# 45. Repairs & Maintenance:
#     Question: Summarize the clauses on landlord obligations for repairs and maintenance, landscaping, cleaning common areas, and ensuring the proper functioning of utilities, as well as promptly addressing repair requests from tenants
#     Answer: Landlord shall maintain the structural elements of the Building and perform capital repairs/replacement of the roof. Landlord shall repair any damages caused by Casualty, subject to the lease provisions.
#
# 46. Utilities:
#     Question: Summarize the clauses on utilities provided by the landlord as part of base rent or operating expenses and what happens if there are any overages.
#     Answer: This document is silent on any utilities provided by Landlord. Tenant is responsible for all utilities.
#
# 47. Events of Default:
#     Question: Summarize what are the specific conditions or actions that could trigger a lessee default under the agreement
#     Answer: Events of default include failing to pay rent within 5 days of due date; failing to perform non-monetary obligations within 15 days after notice; tenant bankruptcy/insolvency; and breach of lease obligations regarding hazardous materials.
#
# 48. Landlord Remedies:
#     Question: Explain in detail what happens in the event of default, what are landlord remedies and cure period.
#     Answer: Upon an event of default, Landlord may terminate Tenant's right to possess the premises and re-enter/relet the premises. Landlord may also terminate the lease, recover damages and exercise other remedies. Landlord shall provide written notice and 15 days to cure monetary defaults, and 30 days to cure non-monetary defaults.
#
# 49. Termination Notice Period:
#     Question: If the tenant does not wish to renew is there a notice period required for ending the initial term or does it automatically end? Explain, what are the conditions and procedures?
#     Answer: This document is silent on any termination notice requirements. The initial term automatically ends on the expiration date.
#
# 50. Unilateral Tenant Termination Rights:
#     Question: Does the tenant have the right to terminate the lease early, within the binding period of the agreement?
#     Answer: Tenant cannot terminate this lease early.
#
# 51. Subordination, Attornment:
#     Question: Summarize all the clauses on subordination and attornment- listing both separately.
#     Answer: The lease is subordinate to any future mortgage. Tenant shall attorn to any transferee or successor of Landlord.
#
# 52. Destruction, Fire & Casualty:
#     Question: Summarize all the clauses on destruction of property, what happens in the event of fire or any such similar event of casualty.
#     Answer: Describes Landlord's and Tenant's termination rights if Premises cannot be restored within certain time periods after Casualty. Addresses Landlord's obligations to repair and restore Premises subject to limitations. Tenant responsible for deductibles and any uninsured Tenant Damage.
#
# 53. Estoppel:
#     Question: Summarize in simple english the clause on estoppel, scope, preclusion of contradictory claims and enforceability.
#     Answer: Upon request, Tenant shall execute an estoppel certificate certifying certain information regarding the lease and defaults. Failure to deliver may allow reliance on information provided by Landlord.
#
# 54. Indemnity:
#     Question: Summarize all clauses in simple english on scope of indemnification, indemnification trigger events, limitations and exclusions, notice and defense obligations, survival of indemnity obligations and enforceability and remedies.
#     Answer: Tenant shall release, indemnify and defend Landlord against various claims arising from Tenant's use of premises, defaults under lease, negligent acts, accidents/injuries, breach of hazardous material obligations, etc., subject to certain limitations. Landlord provides similar indemnity to Tenant regarding hazardous materials Landlord brings to property. Obligations survive termination of lease.
#
# 55. Eminent Domain, Condemnation:
#     Question: Summarize all clauses in simple english on emninent domain and condemnation.
#     Answer: Describes Landlord's and Tenant's termination rights if a Taking renders premises unsuitable for Tenant's use. Addresses Landlord's restoration obligations and abatement of Rent. Tenant waives claims to condemnation award attributable to its leasehold interest.
#
# 56. Landlord Address for Notices:
#     Question: What is the complete physical address to send notices to lessor?
#     Answer: Opus Northwest, L.L.C.
#     1855 Blake Street, Suite 200
#     Denver, Colorado 80202
#     Attn: John M. Shaw
#
# 57. Landlord Contact:
#     Question: Who is the landlord contact for notices- capture the first and last name?
#     Answer: John M. Shaw
#
# 58. Landlord Contact Information:
#     Question: If email or phone number is provided for the landlord contact for notices, capture that
#     Answer: Phone: 303-297-3700
#     Facsimile: 303-297-3300
#
# 59. Tenant Address for Notices:
#     Question: What is the complete physical address to send notices to lessee?
#     Answer: Advanced Digital Information Corporation
#     PO Box 97057
#     Redmond, Washington 98073-9757
#     Attn: John Gacek
#
# 60. Tenant Contact:
#     Question: Who is the tenant contact for notices- capture the first and last name
#     Answer: John Gacek
#
# 61. Tenant Contact Information:
#     Question: If email or phone number is provided for the tenant contact for notices, capture that
#     Answer: Phone: (425) 895-3187
#     Facsimile: (425) 881-2296
